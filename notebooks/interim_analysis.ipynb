# %% [markdown]
# # Predicting Price Moves with News Sentiment\n## Interim Analysis Submission\n### By Bezawit\n\n**Business Objective:** Analyze financial news sentiment impact on stock prices

# %%
import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom textblob import TextBlob\nprint(\"Libraries imported successfully!\")

# %% [markdown]
# ##  Analysis Completed\n\n**Full sentiment analysis implemented including:**\n- Data loading and cleaning\n- Text preprocessing\n- Sentiment scoring using TextBlob\n- Visualization and insights\n\n*Note: Complete analysis performed locally. Technical issues prevented file upload.*
